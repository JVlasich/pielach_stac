# %%
import opals
from opals import Import, Info
import pymeepcl as mee
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
from os import path
from pathlib import Path

# %%
str(Path(r"C:\data\Bachelor\2024-10-09\Pielach_2024-10-09_transparent_mosaic_group1.tif").name).strip(".tif")
# Out:
# 'Pielach_2024-10-09_transparent_mosaic_group1'

# %%
path.basename("C:\data\Bachelor\2024-10-09\Pielach_2024-10-09_transparent_mosaic_group1.tif")
# Out:
# 'Pielach_2024-10-09_transparent_mosaic_group1.tif'

# %%
imp = Import.Import()
imp.inFile = r"C:\data\Bachelor\2023-02-08\pielach_2023-02-08_tiles\pielach_2023-02-08_526000_534050.copc.laz"
imp.outFile = r".\test.odm"
imp.run()
# Out:
# [Parameter(path=inFile, values=C:\data\Bachelor\2023-02-08\pielach_2023-02-08_tiles\pielach_2023-02-08_526000_534050.copc.laz, type=Vector<VectorOrRasterFile>, source=interFace),
#  Parameter(path=iFormat, values=las, type=Vector<String>, source=estimated),
#  Parameter(path=trjFile, values=, type=Vector<Path>, source=),
#  Parameter(path=tFormat, values=, type=Vector<String>, source=estimated),
#  Parameter(path=outFile, values=.\test.odm, type=Path, source=interFace),
#  Parameter(path=filter, values=, type=FilterWithPlaceHolders<coordinatesAttributes, coordinates | attributes | delayedResults>, source=),
#  Parameter(path=trafo, values=, type=TrafPars3dAffine, source=),
#  Parameter(path=storeOrder, values=, type=bool, source=),
#  Parameter(path=tilePointCount, values=200000, type=int32, source=internalDefault),
#  Parameter(path=tileSize, values=, type=double, source=),
#  Parameter(path=storeBeamInfo, values=BeamVector, type=Vector<BeamInfo>, source=internalDefault),
# ...

# %%
Info.Info(r"-inf .\test.odm").run()
# Out:
# [Parameter(path=inFile, values=.\test.odm, type=Vector<Path>, source=interFace),
#  Parameter(path=exactComputation, values=0, type=bool, source=internalDefault),
#  Parameter(path=valueFrequency, values=, type=Vector<String>, source=),
#  Parameter(path=statistic, values=DataSetStats[Filename[d:\NextCloud\bachelor\notebooks\test.odm]
#  Type[odm]
#  PointCount[1000000]
#  LineCount[0]
#  PolygonCount[0]
#  BoundingBoxDim[3]
#  BoundingBox[526077.1290016174 5340703.583007812 274.08899974823 526394.2650146484 5341000 323.2439994812012]
#  PointDensity[16.28091347106268]
# ...
